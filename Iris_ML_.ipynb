# %% [markdown]
# <a href="https://colab.research.google.com/github/bpratik01/ML-projects/blob/main/Iris_ML_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
iris =load_iris()

#converting into a pd dataframe
iris_df = pd.DataFrame(data = iris.data, columns = iris.feature_names)

#make a seperate target clmn representing target values
iris_df['target'] = iris.target

print(iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
iris_df.shape
# Out:
# (150, 5)

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %% [markdown]
# # **Data Visualization**

# %%
sns.set_theme()

# %%
sns.scatterplot(data = iris_df, x = 'sepal length (cm)', y = 'petal width (cm)', hue = 'target')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='petal width (cm)'>

# %%
correlation = iris_df.corr()

# %%
# figure size
plt.figure(figsize=(5, 6))

#  heatmap of correlation matrix
heatmap = sns.heatmap(correlation, cmap='coolwarm', annot=True, fmt='.2f', linewidths=.9, square=True)

plt.title('Correlation Heatmap', fontsize=12)

plt.show()

# %%
X = iris_df.drop(columns=['sepal width (cm)','petal length (cm)'], axis =1)

Y = iris_df['target'].to_numpy()

# Y represents the target columns

# %% [markdown]
# # **Model Training**

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, x_train.shape, x_test.shape)
print(Y.shape, y_train.shape, y_test.shape)
# Out:
# (150, 3) (120, 3) (30, 3)
# (150,) (120,) (30,)

# %%
model = LogisticRegression()

model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
prediction = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, prediction)

accuracy = accuracy * 100

# %%
print(f"Accuracy: {accuracy}%")
# Out:
# Accuracy: 100.0%

# %%
# Create a bar plot to visualize accuracy
plt.figure(figsize=(6, 4))
sns.barplot(x=['accuracy'], y=[accuracy], palette='Blues')
plt.ylim(0, 100)  # Set the y-axis limit to 0-100 for percentage
plt.xlabel('Metrics')
plt.ylabel('Percentage (%)')
plt.title('Model Accuracy')

# Display the accuracy value on top of the bar
plt.text(0, accuracy + 2, f'{accuracy:.2f}%', ha='center', fontsize=12)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.bar(['Accuracy'], [accuracy], color='skyblue')
plt.ylim(0, 100)  # Set the y-axis limit to 0-100 for percentage
plt.xlabel('Metrics')
plt.ylabel('Percentage (%)')
#plt.title('Model Accuracy')

# Display the accuracy value on top of the bar
plt.text('Accuracy', accuracy + 2, f'{accuracy:.2f}%', ha='center', fontsize=12)

# Show the plot
plt.show()
