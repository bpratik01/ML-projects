# %% [markdown]
# # University Marks Predicting model

# %%
#importing dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data collection and Preprocessing

# %%
student_dataset = pd.read_csv('C:\\Users\\prati\\OneDrive\\Desktop\\.vscode\\Projects\\Univ-marks-predict-ML\\student_marks_dataset.csv')

# %%
print(student_dataset.sample)
# Out:
# <bound method NDFrame.sample of                   Name  Sessional Marks  CAT-1  CAT-2  University Marks
# 0      Billy Mcpherson               26      2      7                27
# 1         Felicia Beck               67     35     35                66
# 2        Kelly Jackson               51     32     28                52
# 3         Betty Howell               42     35     25                42
# 4     Melissa Chandler               11     11      0                13
# ..                 ...              ...    ...    ...               ...
# 655  Christine Everett                9     13     24                 7
# 656      Ronald Mendez               20     16     10                23
# 657       Julie Murray               25      8     17                24
# 658    Elizabeth Lucas               45     14     11                46
# 659     Ashley Johnson               40     35     35                43
#
# [660 rows x 5 columns]>

# %%
student_dataset.shape
# Out:
# (660, 5)

# %%
student_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              660 non-null    object
#  1   Sessional Marks   660 non-null    int64
#  2   CAT-1             660 non-null    int64
#  3   CAT-2             660 non-null    int64
#  4   University Marks  660 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 25.9+ KB

# %%
plt.scatter(student_dataset['Sessional Marks'], student_dataset['University Marks'], c = student_dataset['University Marks'])

import numpy as np

x = student_dataset['Sessional Marks']
y = student_dataset['University Marks']

# trendline
coefficients = np.polyfit(x, y, 1)
trendline = np.poly1d(coefficients)

plt.plot(x, trendline(x), color='red', linestyle='--', label='Trendline')

plt.scatter(student_dataset['Sessional Marks'], student_dataset['University Marks'], alpha=0.5)

plt.grid(True)

# %%
X = student_dataset.drop(columns=['Name'], axis =1)

#Y = ['University Marks']
Y = student_dataset['University Marks'].to_numpy()

# Y represents the target columns

# %%
Y.shape
# Out:
# (660,)

# %% [markdown]
# # Train & Test split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, x_train.shape, x_test.shape)
print(Y.shape, y_train.shape, y_test.shape)
# Out:
# (660, 4) (528, 4) (132, 4)
# (660,) (528,) (132,)

# %% [markdown]
# # Model Training
# # Logistic Regression

# %%
model = LogisticRegression()

model.fit(x_train, y_train)
# Out:
# c:\Users\prati\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # Model evaluation -Accuracy Score

# %%
predictions = model.predict(x_test)

# %%
accuracy = accuracy_score(y_test, predictions)

# %%
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 4.55%
